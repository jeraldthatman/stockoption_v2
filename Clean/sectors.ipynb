# %%
sectors_txt = "xly igv fdn xlre xlk xrt jets tan xlv smh ibb xlu itb xlp xlc pho xli xlf xlb moo pbw xme xle gdx"
sectors = sectors_txt.split(' ')
bonds = "lqd" #Invesment grade corporate bond etf

# %%
import yfinance as yf 
import datetime as dt 
yf.pdr_override()
data = yf.download(sectors, period = '1d', interval='2m')
#data.index = data.index.strftime('%Y-%m-%d')
data.index = data.index.strftime('%I:%M')
data.columns.names = ['Info', 'Ticker']

data.head()
# Out:
# [*********************100%***********************]  24 of 24 completed
# Info       Adj Close                                                           \
# Ticker           FDN        GDX         IBB         IGV        ITB       JETS
# Datetime
# 09:30     193.089996  36.880001  131.380005  352.239990  63.860001  22.040001
# 09:32     193.070007  36.710602  131.830002  352.339996  63.820000  22.010000
# 09:34     192.839996  36.860001  131.570007  351.779999  63.630001  21.920000
# 09:36     193.589996  36.900002  131.220001  352.470001  63.810001  21.910000
# 09:38     193.009995  36.985001  131.050003  351.480011  63.980000  21.950001
#
# Info                                                    ...     Volume  \
# Ticker           MOO        PBW        PHO         SMH  ...        XLF
# Datetime                                                ...
# 09:30     104.699997  65.040001  53.750000  282.750000  ...  2598129.0
# ...

# %%
set(data.columns.get_level_values(0))
#data.xs(key=data.columns[0][0], axis=1)
# Out:
# {'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'}

# %%
out = []
for i in sectors:
    out.append((i, yf.Ticker(i.upper()).info['longName']))

# %%
key_map = {k.upper():v for k, v in out}
key_map['FDN']
# Out:
# 'First Trust Dow Jones Internet Index Fund'

# %%
data.columns.get_level_values(1)
# Out:
# Index(['FDN', 'GDX', 'IBB', 'IGV', 'ITB', 'JETS', 'MOO', 'PBW', 'PHO', 'SMH',
#        ...
#        'XLF', 'XLI', 'XLK', 'XLP', 'XLRE', 'XLU', 'XLV', 'XLY', 'XME', 'XRT'],
#       dtype='object', name='Ticker', length=144)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import plotly 
import cufflinks as cf
cf.go_offline()
data.xs('Open', axis = 1, level=0).pct_change().rolling(15).mean().iplot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="492cd0af-8eeb-4b46-87c0-8cfc5c72cceb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
